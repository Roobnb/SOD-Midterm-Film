# %% [markdown]
# # What makes a good movie?
# by Xiaoqing Mei, Songting Liu, and Omar Abdellah

# %% [markdown]
# # Introductions
# Everybody loves movies. No matter who they are, where they come from, or how old they are, every single person has an answer to the question: “What’s your favorite movie?” In fact, we love movies so much that we have multiple ceremonies celebrating them each year, the most famous of which being the Academy Awards, also known as the Oscars. As three avid movie lovers ourselves, we decided to center our project around them, and we thought what better movies to use than the best of the best, the Oscar nominees. In our project, we wanted to explore three main ideas.
#
# If these movies are truly the best of the best, how well were they received?
# We all know that most things improve over time, we wanted to test if the same is true for movies too.
# With many things in life, the more effort you put in, the better the outcome. Does this also apply with money?
#
# As we said, we thought the best place to get our data was from the last 10 years’ Oscar nominees. We decided to take five nominees from each of the last 10 years for 50 movies in total. We decided to look at three main data points for each movie, the year it was nominated, how much was spent to make it, and its critical rating out of 10. To get this data we scraped from the wikipedia pages of each one of the 50 movies. For a list of the 50 movies, see the end of this essay.
#
# Here, we can see exactly how to extract the ratings of each movie from its respective Wikipedia page.

# %% [markdown]
# # Methology
#
# We wanted to know what makes a movie improve throughout each year and whether or not the movie's quality changes according to the budget amount given. So we decided to compare the budget amount and the data as each year progress to see if it has an impact on its ratings for the best picture movies each year.
#
# We utilized Beautifulsoup to request our data from the Wikipedia pages of each movies we chosen from 2014 to 2023, 5 best picture nominees movie from each year which total to 50 movies.

# %%
import requests
from bs4 import BeautifulSoup
import re
import csv



#define a function that tells the rating of a movie
from movie_rating import get_movie_rating

from movie_year import get_movie_year

#Function for getting the budget

from movie_budget import get_movie_budgets




urls=[
    "https://en.wikipedia.org/wiki/Everything_Everywhere_All_at_Once",
    "https://en.wikipedia.org/wiki/Avatar:_The_Way_of_Water",
    "https://en.wikipedia.org/wiki/Elvis_(2022_film)",
    "https://en.wikipedia.org/wiki/Top_Gun:_Maverick",
    "https://en.wikipedia.org/wiki/The_Banshees_of_Inisherin",
    "https://en.wikipedia.org/wiki/Dune_(2021_film)",
    "https://en.wikipedia.org/wiki/West_Side_Story_(2021_film)",
    "https://en.wikipedia.org/wiki/King_Richard_(film)",
    "https://en.wikipedia.org/wiki/CODA_(2021_film)",
    "https://en.wikipedia.org/wiki/Belfast_(film)",
    "https://en.wikipedia.org/wiki/Nomadland_(film)",
    "https://en.wikipedia.org/wiki/The_Father_(2020_film)",
    "https://en.wikipedia.org/wiki/Judas_and_the_Black_Messiah",
    "https://en.wikipedia.org/wiki/Mank",
    "https://en.wikipedia.org/wiki/Minari_(film)",
    "https://en.wikipedia.org/wiki/Parasite_(2019_film)",
    "https://en.wikipedia.org/wiki/Ford_v_Ferrari",
    "https://en.wikipedia.org/wiki/The_Irishman",
    "https://en.wikipedia.org/wiki/Joker_(2019_film)",
    "https://en.wikipedia.org/wiki/Little_Women_(2019_film)",
    "https://en.wikipedia.org/wiki/Green_Book_(film)",
    "https://en.wikipedia.org/wiki/Black_Panther_(film)",
    "https://en.wikipedia.org/wiki/BlacKkKlansman",
    "https://en.wikipedia.org/wiki/Bohemian_Rhapsody_(film)",
    "https://en.wikipedia.org/wiki/A_Star_Is_Born_(2018_film)",
    "https://en.wikipedia.org/wiki/The_Shape_of_Water ",
    "https://en.wikipedia.org/wiki/Call_Me_by_Your_Name_(film)",
    "https://en.wikipedia.org/wiki/Darkest_Hour_(film) ",
    "https://en.wikipedia.org/wiki/Dunkirk_(2017_film)#",
    "https://en.wikipedia.org/wiki/Get_Out ",
    "https://en.wikipedia.org/wiki/Moonlight_(2016_film)",
    "https://en.wikipedia.org/wiki/Arrival_(film)",
    "https://en.wikipedia.org/wiki/Fences_(film)",
    "https://en.wikipedia.org/wiki/Hacksaw_Ridge",
    "https://en.wikipedia.org/wiki/La_La_Land",
    "https://en.wikipedia.org/wiki/Spotlight_(film)",
    "https://en.wikipedia.org/wiki/The_Big_Short_(film)",
    "https://en.wikipedia.org/wiki/The_Martian_(film)",
    "https://en.wikipedia.org/wiki/The_Revenant_(2015_film)",
    "https://en.wikipedia.org/wiki/Mad_Max:_Fury_Road",
    "https://en.wikipedia.org/wiki/Birdman_(film)",
    "https://en.wikipedia.org/wiki/American_Sniper",
    "https://en.wikipedia.org/wiki/The_Grand_Budapest_Hotel",
    "https://en.wikipedia.org/wiki/The_Imitation_Game",
    "https://en.wikipedia.org/wiki/The_Theory_of_Everything_(2014_film)",
    "https://en.wikipedia.org/wiki/12_Years_a_Slave_(film)",
    "https://en.wikipedia.org/wiki/American_Hustle",
    "https://en.wikipedia.org/wiki/Captain_Phillips_(film)",
    "https://en.wikipedia.org/wiki/Dallas_Buyers_Club",
    "https://en.wikipedia.org/wiki/The_Wolf_of_Wall_Street_(2013_film)"






]

# %% [markdown]
# This is where we are scraping data from Wikipedia. At first, we are importing the necessary library we need in order to scrape the data we want. We created 3 different functions scraping data which are the budgets, ratings, and the year of each movies we have selected and store in a separate file of its own. Then we call each function from the file in which we store at each of its designated file .py.

# %%
#Open a CSV file to write


with open('movie_ratings.csv', mode="w", newline="") as file:


    file = open("movie_ratings.csv","w")
    writer = csv.writer(file)
#write a row
    writer.writerow(['Movie','Rating', 'Budget','Year'])



#Loop each urls and get the rating for each movie


for url in urls:
    rating = get_movie_rating(url)
    years = get_movie_year(url)
    budget = get_movie_budgets(url)
    movie_title = url.split("/")[-1].replace("_"," ").title()

    #print(movie_title, rating, years+1, budget)
    writer.writerow([movie_title, rating, budget, years+1 ])

# %% [markdown]
# Once we received all of our data, we decided that we want to store it in a csv file so we can utilize it to generate our graphs. we created a for loop to record the data in the csv file. The writer.writerow function essentially will execute output in that specific order we want and it will generate the same set of data for each url we have listed given the effect of the for loop.

# %% [markdown]
# # Results

# %%
import matplotlib.pyplot as plt
import pandas as pd



# Read the CSV file into a Pandas DataFrame
df = pd.read_csv("movie_ratings.csv")


# Split the rating column by the '/' separator and keep only the first value as a float
df['Rating'] = df['Rating'].apply(lambda x: float(x.split('/')[0]))


# Sort the DataFrame by rating in descending order
df = df.sort_values(by='Rating', ascending=False)


# Create a horizontal bar chart
fig, ax = plt.subplots(figsize=(8, 12))
ax.barh(df['Movie'], df['Rating'], color='blue')


# Set the x-axis label
ax.set_xlabel('Rating')


# Set the title
ax.set_title('Movie Ratings')


# Show the plot
plt.show()

# %% [markdown]
# Figure.1
# Figure.1 shows the ratings of the Oscars "Academy Award for Best Picture" nominees from 2014 to 2023
#
#
# Next we will look at the average rating for each year's nominees.

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Read the CSV file into a DataFrame




df = pd.read_csv('movie_ratings.csv')




df['Rating'] = df['Rating'].apply(lambda x: float(x.split('/')[0]))


# convert the 'Year' column to datetime format and sort the dataframe by 'Year'
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
df = df.sort_values('Year')


# calculate the average rating for each year
avg_ratings = df.groupby(df['Year'].dt.year)['Rating'].mean()


# plot a bar graph of average ratings against years
plt.bar(avg_ratings.index, avg_ratings)
plt.xticks(avg_ratings.index)
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.title('Average Ratings of Movies by Year')
plt.ylim(6,9)




plt.show()

# %% [markdown]
# Figure.2
# Figure.2 shows the average rating (1-10) of each year's nominees for Oscar "Academy Award for Best Picture"
#
#
# Then we will look at the average rating of nominees with different budget range

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Read the csv file
df = pd.read_csv('movie_ratings.csv')




df['Rating'] = df['Rating'].apply(lambda x: float(x.split('/')[0]))


# Define the budget ranges
budget_ranges = [(0, 25), (25, 50), (50, 75), (75, 100), (100, float('inf'))]


# Create a new column for Budget Range
df['budget Range'] = pd.cut(df['Budget'], bins=[r[0] for r in budget_ranges] + [float('inf')], labels=[f"${r[0]}-${r[1]}" for r in budget_ranges])


# Group the data by Budget Range and calculate the average rating
grouped = df.groupby('budget Range')['Rating'].mean()


# Create the bar chart
plt.bar(grouped.index, grouped.values)


# Set the title and labels
plt.title('Average Movie Rating by Budget Range')
plt.xlabel('Budget Range in $ million')
plt.ylabel('Average Rating')
plt.ylim(6,9)


# Show the plot
plt.show()

# %% [markdown]
# Figure.3
# Figure.3 shows the average rating (1-10) for nominees for "Academy Award for Best Picture"
#
#
# By visualizing the data, we are able to clearly compare the ratings for all these "best of the best'' movies. By sorting the movies by years, we see that the average rating of the movies do not necessarily go up as time goes on, also more money does not guarantee high reviews.

# %% [markdown]
# # Conclusion
#
# After carefully analyzing these movies and the different factors affecting them, it can be concluded that there is no perfect - or even good - predictor at how a movie will be rated. Despite technology improving over the years, we did not see a noticeable positive correlation between year and movie rating, seen through the seemingly random distribution of average ratings. Furthermore, as is seen in the Budget vs Rating graph, there is no positive correlation there either. Surprisingly, this suggests that more money spent making a movie does not mean a better received movie.
#
# As we said, there is no real good predictor to how a movie will be received. People have been enjoying movies for ages, long before VFX effects and multi-million dollar budgets. It seems that the most important factor for a movie to have is a good story, something that cannot be bought and transcends time.
